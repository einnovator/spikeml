# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=<Your API access key>
# %env CLEARML_API_SECRET_KEY=<Your API secret key>
# %env CLEARML_API_ACCESS_KEY=7FQ666BBVF2FPYU0A6XNPTPRXQEJ2K
# %env CLEARML_API_SECRET_KEY=drCY69rTVFkAd4gRo_pt7F2frsX4TcXQ0IijWG1pYM_01vvw3k1U23xagBwRU-Rl23k
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=<Your API access key>
# env: CLEARML_API_SECRET_KEY=<Your API secret key>
# env: CLEARML_API_ACCESS_KEY=7FQ666BBVF2FPYU0A6XNPTPRXQEJ2K
# env: CLEARML_API_SECRET_KEY=drCY69rTVFkAd4gRo_pt7F2frsX4TcXQ0IijWG1pYM_01vvw3k1U23xagBwRU-Rl23k

# %%
from clearml import Task
task = Task.init(project_name="test", task_name="task0")
# Out:
# ClearML Task: created new task id=3e680f8d09d144fa8894b7ea105a987f
# 2025-11-15 15:36:28,970 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/79941ed00c2546639ba27ee00a0e597f/experiments/3e680f8d09d144fa8894b7ea105a987f/output/log
# ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start
# Retrying (Retry(total=237, connect=238, read=239, redirect=240, status=240)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001835AE51E40>: Failed to resolve 'api.clear.ml' ([Errno 11001] getaddrinfo failed)")': /v2.23/tasks.get_all
# Retrying (Retry(total=237, connect=237, read=240, redirect=240, status=240)) after connection broken by 'NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001835FECA140>: Failed to resolve 'api.clear.ml' ([Errno 11001] getaddrinfo failed)")': /v2.23/events.add_batch
# ...
