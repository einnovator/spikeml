# %%
# %load_ext autoreload
# %autoreload 2

import sys
for p in ['../../../../src']:
    if p not in sys.path:
        sys.path.append(p)
        
from spikeml.utils.filter_util import filter, filter_count
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
assert filter('a', {'include': ['a']})
